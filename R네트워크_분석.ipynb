# %% [markdown]
# <a href="https://colab.research.google.com/github/Welle-Kim/Python/blob/master/R%EB%84%A4%ED%8A%B8%EC%9B%8C%ED%81%AC_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
setwd("C:\02.내부자료\분석역량\4. R_연결망\.RData")
rm(list=ls())
library(stringr)
library(plyr)
library(networkD3)
library(KoNLP)
library(htmlwidgets)
install.packages("remotes")
remotes::install_github('haven-jeon/KoNLP', upgrade = "never", INSTALL_opts=c("--no-multiarch"))
library(KoNLP)
install.packages("multilinguer")
library(multilinguer)
install_jdk()
install.packages('rJava', type = 'binary');library(rJava);.jinit();rstudioapi::restartSession()
rm(list=ls())
library(multilinguer)
library(stringr)
library(plyr)
library(networkD3)
library(KoNLP)
install.packages("KoNLP")
remotes::install_github('haven-jeon/KoNLP', upgrade = "never", INSTALL_opts=c("--no-multiarch"))
# java, rJava ?�치 install.packages("multilinguer")
# ?�때 mac ?�용?�는 ?�스?�탑 비�?번호�?물어봅니?? ?�력?�줘???�치가 진행?�니??
install.packages("multilinguer")
install.packages("multilinguer")
library(multilinguer)
install_jdk()
install.packages('rJava', type = 'binary');library(rJava);.jinit();rstudioapi::restartSession()
# ?�존???�키지 ?�치
install.packages(c('stringr', 'hash', 'tau', 'Sejong', 'RSQLite', 'devtools'), type = "binary")
# 64bit ?�서�??�작?�니??
remotes::install_github('haven-jeon/KoNLP', upgrade = "never", INSTALL_opts=c("--no-multiarch"))
# 64bit ?�서�??�작?�니??
remotes::install_github('haven-jeon/KoNLP', upgrade = "never", INSTALL_opts=c("--no-multiarch"))
# github 버전 ?�치
install.packages("remotes")
install.packages("remotes")
# 64bit ?�서�??�작?�니??
remotes::install_github('haven-jeon/KoNLP', upgrade = "never", INSTALL_opts=c("--no-multiarch"))
library(KoNLP)
library(htmlwidgets)


##여기부터 다시
Link<-read.csv("?�인_?�반?�성_2019_link.csv",stringsAsFactors = FALSE)
Node<-read.csv("?�인_?�반?�성_2019_node.csv",stringsAsFactors = FALSE)
net_HS<-forceNetwork(Links = Link,
Nodes = Node,
Source = "source_idx",
Target = "target_idx",
Value = "n",
NodeID = "node",
Nodesize = "size",
Group = "group",
height = 800,
width = 1500,
fontSize = 1,
#fontFamily = "C:/Users/RSN/AppData/Local/Microsoft/Windows/Fonts/NanumSquare.ttf",
linkDistance = 200,
linkColour = "#E2E2E2",
#colourScale = JS("d3.scaleOrdinal(d3.schemeCategory10);"),
colourScale = JS("d3.scaleOrdinal(['#70AD47','#9BB7D4','#A5A5A5','#FDAC53','#E0B589','#385723','#E9897E']);"),
charge=-1000,
radiusCalculation = JS("Math.sqrt(d.nodesize)/4"),
#radiusCalculation = JS("Math.pow(d.nodesize,2/3)"),
linkWidth = JS("function(d) { return Math.sqrt(d.value)/6; }"),
#linkWidth = JS("function(d) { return Math.sqrt(d.value)^(1/5); }"),
opacity = 0.8,
zoom = TRUE,
legend = TRUE,
#bounded = TRUE,
opacityNoHover=TRUE
)
library(networkD3)
net_HS<-forceNetwork(Links = Link,
Nodes = Node,
Source = "source_idx",
Target = "target_idx",
Value = "n",
NodeID = "node",
Nodesize = "size",
Group = "group",
height = 800,
width = 1500,
fontSize = 1,
#fontFamily = "C:/Users/RSN/AppData/Local/Microsoft/Windows/Fonts/NanumSquare.ttf",
linkDistance = 200,
linkColour = "#E2E2E2",
#colourScale = JS("d3.scaleOrdinal(d3.schemeCategory10);"),
colourScale = JS("d3.scaleOrdinal(['#70AD47','#9BB7D4','#A5A5A5','#FDAC53','#E0B589','#385723','#E9897E']);"),
charge=-1000,
radiusCalculation = JS("Math.sqrt(d.nodesize)/4"),
#radiusCalculation = JS("Math.pow(d.nodesize,2/3)"),
linkWidth = JS("function(d) { return Math.sqrt(d.value)/6; }"),
#linkWidth = JS("function(d) { return Math.sqrt(d.value)^(1/5); }"),
opacity = 0.8,
zoom = TRUE,
legend = TRUE,
#bounded = TRUE,
opacityNoHover=TRUE
)
saveWidget(get("net_HS"),
file=paste("ex",".html")) # 처占?�옙 ?????�쏙????????�? ?? ?? html???? ?????
net_HS<-forceNetwork(Links = Link,
Nodes = Node,
Source = "source_idx",
Target = "target_idx",
Value = "n",
NodeID = "node",
Nodesize = "size",
Group = "group",
height = 800,
width = 1500,
fontSize = 20,
#fontFamily = "C:/Users/RSN/AppData/Local/Microsoft/Windows/Fonts/NanumSquare.ttf",
linkDistance = 200,
linkColour = "#E2E2E2",
#colourScale = JS("d3.scaleOrdinal(d3.schemeCategory10);"),
colourScale = JS("d3.scaleOrdinal(['#70AD47','#9BB7D4','#A5A5A5','#FDAC53','#E0B589','#385723','#E9897E']);"),
charge=-1000,
radiusCalculation = JS("Math.sqrt(d.nodesize)/4"),
#radiusCalculation = JS("Math.pow(d.nodesize,2/3)"),
linkWidth = JS("function(d) { return Math.sqrt(d.value)/6; }"),
#linkWidth = JS("function(d) { return Math.sqrt(d.value)^(1/5); }"),
opacity = 0.8,
zoom = TRUE,
legend = TRUE,
#bounded = TRUE,
opacityNoHover=TRUE
)
saveWidget(get("net_HS"),
file=paste("ex",".html")) # 처占?�옙 ?????�쏙????????�? ?? ?? html???? ?????
q()
