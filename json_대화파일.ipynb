# %% [markdown]
# <a href="https://colab.research.google.com/github/Welle-Kim/Python/blob/master/json_%EB%8C%80%ED%99%94%ED%8C%8C%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("script_part_06.csv",encoding="cp949")
df
# Out:
#                                                       Q  \
# 0     아따, 나 대가리 털나고 뉴스 시간 생방송 중에 사고난 건 처음 보네. 아따, 세상...
# 1                                                안녕하세요?
# 2                               어~ 선우 왔나. 얼른 들어와서 밥 무라.
# 3                                  어, 언능 와서, 어? 한 그릇 해.
# 4                                                어? 언니!
# ...                                                 ...
# 1050                                              부탁이요?
# 1051          어, 다른 게 아니고 네 동생 공무원 될 때까지 네가 좀 데리고 있으라고.
# 1052                                                 예?
# 1053        아, 이 놈의 새끼 안 들어오고 뭐 하는 거야. 얼른 들어와! 아휴, 들어와.
# 1054                                             아, 엄마.
#
#                                                       A
# 0                                                안녕하세요?
# 1                               어~ 선우 왔나. 얼른 들어와서 밥 무라.
# 2                                  어, 언능 와서, 어? 한 그릇 해.
# 3                          아, 아니에요. 저 택이 방에서 애들이랑 라면 먹.
# ...

# %%
df=df.drop_duplicates(["Q","A"])
df
# Out:
#                                                       Q  \
# 0     아따, 나 대가리 털나고 뉴스 시간 생방송 중에 사고난 건 처음 보네. 아따, 세상...
# 1                                                안녕하세요?
# 2                               어~ 선우 왔나. 얼른 들어와서 밥 무라.
# 3                                  어, 언능 와서, 어? 한 그릇 해.
# 4                                                어? 언니!
# ...                                                 ...
# 1050                                              부탁이요?
# 1051          어, 다른 게 아니고 네 동생 공무원 될 때까지 네가 좀 데리고 있으라고.
# 1052                                                 예?
# 1053        아, 이 놈의 새끼 안 들어오고 뭐 하는 거야. 얼른 들어와! 아휴, 들어와.
# 1054                                             아, 엄마.
#
#                                                       A
# 0                                                안녕하세요?
# 1                               어~ 선우 왔나. 얼른 들어와서 밥 무라.
# 2                                  어, 언능 와서, 어? 한 그릇 해.
# 3                          아, 아니에요. 저 택이 방에서 애들이랑 라면 먹.
# ...

# %%
cript_j=[]
for i in df['A']:
  for b in df["Q"]:
    script_j.append(i)
    script_j.append(b)

# %%
print(len(set(script_j)))
# Out:
# 1174
