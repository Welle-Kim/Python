# %% [markdown]
# <a href="https://colab.research.google.com/github/Welle-Kim/Python/blob/master/%ED%95%9C%EA%B0%9C_%EC%B6%94%EC%B6%9C(%EC%99%84%EC%84%B1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
lst = os.listdir("/content/drive/MyDrive/Part06_csv")
lst.remove(".DS_Store")
for part in lst:
  print(part)
  dir_lst=os.listdir(ps+"/"+part)
  print(dir_lst)
# Out:
# 202207081630320
# ...

# %%
df0=pd.DataFrame()
for dir in dir_lst:
  df=pd.read_csv(dir)
  df0=pd.concat([df0,df],ignore_index=True)

# %%
df0
# Out:
#      Index Modification Speaker  Start Time  End Time  \
# 0        1         인식결과       1        1180      1690
# 1        1         수정결과       A        1180      1690
# 2        2         인식결과       2        4230      9390
# 3        2         수정결과       B        4230      9390
# 4        3         인식결과       1       12730     14890
# ..     ...          ...     ...         ...       ...
# 879      6         수정결과       A       22880     25540
# 880      7         인식결과       2       25780     27740
# 881      7         수정결과       B       25780     27740
# 882      8         인식결과       1       28180     28640
# 883      8         수정결과       A       28180     28640
#
#                                       Script
# 0                                          아
# 1                                          아
# 2    형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.
# 3    형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.
# 4                           아 시끄러우면 집중 안 되는데
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#     Index Modification Speaker  Start Time  End Time  \
# 2       2         인식결과       2         830     10240
# 3       2         수정결과       B         830     10240
# 4       3         인식결과       2       10430     11990
# 5       3         수정결과       B       10430     11990
# 6       4         인식결과       1       12880     16379
# 7       4         수정결과       A       12880     16379
# 8       5         인식결과       2       16379     20940
# 9       5         수정결과       B       16379     20940
# 10      6         인식결과       1       22880     25540
# 11      6         수정결과       A       22880     25540
# 12      7         인식결과       2       25780     27740
# 13      7         수정결과       B       25780     27740
# 14      8         인식결과       1       28180     28640
# 15      8         수정결과       A       28180     28640
#
#                                            Script
# 2   오 이쁘네 아 근데 이거 깁스에 쓴 글씨가 잘 안 보이네 이거 글씨 보여야 되는데
# 3   오 이쁘네 아 근데 이거 깁스에 쓴 글씨가 잘 안 보이네 이거 글씨 보여야 되는데
# ...

# %%
sample_df=df.iloc[0:49:2,-1]
sample_df
# Out:
# 2     오 이쁘네 아 근데 이거 깁스에 쓴 글씨가 잘 안 보이네 이거 글씨 보여야 되는데
# 4                                      수경 누나가 써준 건데
# 6        수경 언니가 써준 글씨 때문에 지금 내 팔 거리 안 하겠다는 거예요. 그래서
# 8             아 누가 안 한대 글씨 보이게 한다는 거지 이거 내 명함 대신이니까
# 10                           팔걸이 만들어 줬으니까 나도 선물 줘요.
# 12                                    아 그래 뭐 갖고 싶은데
# 14                                               이거
# Name: Script, dtype: object

# %%
script=[]
for i in sample_df:
  script.append(i)

# %%
script
# Out:
# [nan,
#  '오 이쁘네 아 근데 이거 깁스에 쓴 글씨가 잘 안 보이네 이거 글씨 보여야 되는데',
#  '수경 누나가 써준 건데',
#  '수경 언니가 써준 글씨 때문에 지금 내 팔 거리 안 하겠다는 거예요. 그래서',
#  '아 누가 안 한대 글씨 보이게 한다는 거지 이거 내 명함 대신이니까',
#  '팔걸이 만들어 줬으니까 나도 선물 줘요.',
#  '아 그래 뭐 갖고 싶은데',
#  '이거']
