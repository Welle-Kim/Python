# %% [markdown]
# <a href="https://colab.research.google.com/github/Welle-Kim/Python/blob/master/%ED%95%9C%EA%B0%9C_%EC%B6%94%EC%B6%9C(%EC%A7%84%EC%A7%9C%EC%99%84%EC%84%B1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
ps="/content/drive/MyDrive/Part06_csv"

# %%
lst = os.listdir("/content/drive/MyDrive/Part06_csv")
lst.remove(".DS_Store")
for part in lst:
  print(part)
  dir_lst=os.listdir(ps+"/"+part)
  print(dir_lst)
# Out:
# 202207081630320
# ...

# %%
df0=pd.DataFrame()
for dir in dir_lst:
  df=pd.read_csv(dir)
  df0=pd.concat([df0,df],ignore_index=True)

# %%
df0
# Out:
#      Index Modification Speaker  Start Time  End Time  \
# 0        1         인식결과       1        1180      1690
# 1        1         수정결과       A        1180      1690
# 2        2         인식결과       2        4230      9390
# 3        2         수정결과       B        4230      9390
# 4        3         인식결과       1       12730     14890
# ..     ...          ...     ...         ...       ...
# 879      6         수정결과       A       22880     25540
# 880      7         인식결과       2       25780     27740
# 881      7         수정결과       B       25780     27740
# 882      8         인식결과       1       28180     28640
# 883      8         수정결과       A       28180     28640
#
#                                       Script
# 0                                          아
# 1                                          아
# 2    형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.
# 3    형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.
# 4                           아 시끄러우면 집중 안 되는데
# ...

# %%
df1=df0.dropna()

# %%
df1
# Out:
#      Index Modification Speaker  Start Time  End Time  \
# 0        1         인식결과       1        1180      1690
# 1        1         수정결과       A        1180      1690
# 2        2         인식결과       2        4230      9390
# 3        2         수정결과       B        4230      9390
# 4        3         인식결과       1       12730     14890
# ..     ...          ...     ...         ...       ...
# 879      6         수정결과       A       22880     25540
# 880      7         인식결과       2       25780     27740
# 881      7         수정결과       B       25780     27740
# 882      8         인식결과       1       28180     28640
# 883      8         수정결과       A       28180     28640
#
#                                       Script
# 0                                          아
# 1                                          아
# 2    형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.
# 3    형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.
# 4                           아 시끄러우면 집중 안 되는데
# ...

# %%
sample_df=df1.iloc[0:884:2,-1]
sample_df
# Out:
# 0                                               아
# 2         형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.
# 4                                아 시끄러우면 집중 안 되는데
# 6                          공복이라서 예민하신 거 아닐까요. 작가님
# 8                                             아 저
#                           ...
# 874    수경 언니가 써준 글씨 때문에 지금 내 팔 거리 안 하겠다는 거예요. 그래서
# 876         아 누가 안 한대 글씨 보이게 한다는 거지 이거 내 명함 대신이니까
# 878                        팔걸이 만들어 줬으니까 나도 선물 줘요.
# 880                                 아 그래 뭐 갖고 싶은데
# 882                                            이거
# Name: Script, Length: 386, dtype: object

# %%
script=[]
for i in sample_df:
  script.append(i)

# %%
script
# Out:
# ['아',
#  '형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.',
#  '아 시끄러우면 집중 안 되는데',
#  '공복이라서 예민하신 거 아닐까요. 작가님',
#  '아 저',
#  '샌드위치 있습니다. 이것 좀 드세요.',
#  '아 무슨 소리지 나 방에서 음식도 안 먹는데 이거 당장 지워주세요.',
#  '아 네 죄송합니다.',
#  '아 죄송합니다. 어떡해 죄송합니다.',
#  '이거 닦으려면 잔물에 구연산하고 식초 뿌려서 팍팍 문질러 닦아질까 말까 한데',
#  '집에 구연산이 있던가',
#  '야 너희가 발바닥 시커매 당장 화장실 가서 씻어',
#  '아 형',
#  '아 내가 지금 그럴 만한 마음이 여유가 없어 나 방금 전에 사기까지 당하고 그리고 마감까지 몇 시간 남지도 않았거든',
#  '야 당장 가서 시대',
#  '너 옷에 왜 이렇게 뭐 먼지가 많아 니 인생 마감하기 싫으면 당장 가서 씻어',
#  '씻을게',
#  '뭐 어디 그',
#  '이런 말을 어디 감히',
#  '바닥에 발바닥 대지 말고',
#  '발바닥 안 데고 어떻게 가',
#  '나 따라와',
#  '하 어서 뭐 해 따라와',
#  '사장님 저 때문에 계속 창문 열고 와서 너무 추웠죠',
#  '괜찮아 영자 씨 입덧 때문에 멀미하는 것보다 낫지',
#  '수발아 넌 어떻게 이렇게 어리숙한 보이스피싱에 속냐',
#  '보이스피싱이요 내 주민등록번호랑 이름 다 알고 있던데 게다가 검사라길래 말입니다. 아이고',
#  '아 이렇게 순진해 빠져서 너 이 험난한 세상 어떻게 살라고 그래 너는 나 아니었으면 큰일 날 뻔했어',
#  '아 그러게요 아 작가님 아니었으면 저 엄마한테 부칠 돈 다 날려먹을 뻔 했습니다.',
#  '아 맞다 나 돈 붙여야 되는데 작가님 저 잠깐 은행에 좀 다녀오겠습니다.',
#  '너 엄마한테 붙이는 거 확실해',
#  '네 확실하게 엄마한테 보증금 빌린 거 갚는 겁니다.',
#  '그래 다녀와 네 다녀오겠습니다.',
# ...
