# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from urllib.parse import quote
import requests
import time
import pandas as pd
import re
import csv
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

from selenium import webdriver

driver = webdriver.Chrome("/opt/homebrew/bin/chromedriver")
# driver = webdriver.Chrome("c:/pydata/chromedriver")
review_data=[]

kakaopage=[146656,61476,143722,110137,144508,107497,111490,121982,150296,122296]

for k in kakaopage:
    driver.get("https://movie.daum.net/moviedb/crew?movieId="+str(k))
    driver.execute_script("window.scrollTo(0, 53)") 
    
    html = driver.page_source
    soup=bs(html,"html.parser")
    
    title=soup.find("span",class_='txt_tit').text
    genre=soup.find_all("dl",class_="list_cont")[1]
    genre=str(genre)
    genre=re.sub('[^ ㄱ-ㅣ가-힣+a-zA-Z]','',genre)
    genre=genres.text.replace("장르\n","").strip()
    director=soup.find("a",class_="link_txt").text
    
#     #주연배우
#     main_soup=soup.find_all("div", class_="item_crew")
#     main_actor=main_soup[0].find("strong", class_="tit_item")
     
#     try:
#         main_actor=director.text
            
#     except AttributeError as err:
#          main_actor="주연배우미상"
    
    
    reviews=soup.find_all("ul",class_="list_crew")
    
    for review in reviews:
        try:
            main_actor=reviews[1].find("a",class_="link_txt").text
        
        except AttributeError as err:
                continue
        
        review_data.append([title,genre,director,main_actor])
    

driver.close()
        
df=pd.DataFrame(review_data,columns=["title","genre","director","main_actor"])
display(df.head(10))
display(df.tail(10))
# df.to_csv("./kakaopage_test.csv",header=True,index=False,encoding="utf8")
# df.to_excel("./kakaopage_test.xlsx",header=True,index=False)

print("작업이 완료되었습니다.")
# Out:
# /var/folders/6n/yywnll5x3_1cc4p34yq_4c_w0000gn/T/ipykernel_19123/856252103.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/opt/homebrew/bin/chromedriver")
#         title       genre            director main_actor
# 0  드래곤 길들이기 3  액션/어드벤처/SF  91회 미국비평가협회상, 2019     제이 바루첼
# 1  드래곤 길들이기 3  액션/어드벤처/SF  91회 미국비평가협회상, 2019     제이 바루첼
# 2  드래곤 길들이기 3  액션/어드벤처/SF  91회 미국비평가협회상, 2019     제이 바루첼
#         title       genre            director main_actor
# 0  드래곤 길들이기 3  액션/어드벤처/SF  91회 미국비평가협회상, 2019     제이 바루첼
# 1  드래곤 길들이기 3  액션/어드벤처/SF  91회 미국비평가협회상, 2019     제이 바루첼
# 2  드래곤 길들이기 3  액션/어드벤처/SF  91회 미국비평가협회상, 2019     제이 바루첼
# 작업이 완료되었습니다.
