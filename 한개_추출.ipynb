# %% [markdown]
# <a href="https://colab.research.google.com/github/Welle-Kim/Python/blob/master/%ED%95%9C%EA%B0%9C_%EC%B6%94%EC%B6%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
lst = os.listdir("/content/drive/MyDrive/Part06_csv")
lst.remove(".DS_Store")
for part in lst:
  # print(part)
  dir_lst=os.listdir(ps+"/"+part)
  print(dir_lst)
# Out:
# ['KETI_MULTIMODAL_0000001127_20220708_163032.csv', 'KETI_MULTIMODAL_0000001125_20220708_163032.csv', 'KETI_MULTIMODAL_0000001157_20220708_163032.csv', 'KETI_MULTIMODAL_0000001130_20220708_163032.csv', 'KETI_MULTIMODAL_0000001114_20220708_163032.csv', 'KETI_MULTIMODAL_0000001107_20220708_163032.csv', 'KETI_MULTIMODAL_0000001116_20220708_163032.csv', 'KETI_MULTIMODAL_0000001148_20220708_163032.csv', 'KETI_MULTIMODAL_0000001134_20220708_163032.csv', 'KETI_MULTIMODAL_0000001115_20220708_163032.csv', 'KETI_MULTIMODAL_0000001117_20220708_163032.csv', 'KETI_MULTIMODAL_0000001131_20220708_163032.csv', 'KETI_MULTIMODAL_0000001158_20220708_163032.csv', 'KETI_MULTIMODAL_0000001152_20220708_163032.csv', 'KETI_MULTIMODAL_0000001153_20220708_163032.csv', 'KETI_MULTIMODAL_0000001109_20220708_163032.csv', 'KETI_MULTIMODAL_0000001122_20220708_163032.csv', 'KETI_MULTIMODAL_0000001155_20220708_163032.csv', 'KETI_MULTIMODAL_0000001137_20220708_163032.csv', 'KETI_MULTIMODAL_0000001145_20220708_163032.csv
# ...

# %%
for dir in dir_lst:
  print(dir)
# Out:
# KETI_MULTIMODAL_0000001076_20220708_163014.csv
# KETI_MULTIMODAL_0000001077_20220708_163014.csv
# KETI_MULTIMODAL_0000001069_20220708_163014.csv
# KETI_MULTIMODAL_0000001098_20220708_163014.csv
# KETI_MULTIMODAL_0000001064_20220708_163014.csv
# KETI_MULTIMODAL_0000001091_20220708_163014.csv
# KETI_MULTIMODAL_0000001088_20220708_163014.csv
# KETI_MULTIMODAL_0000001096_20220708_163014.csv
# KETI_MULTIMODAL_0000001083_20220708_163014.csv
# KETI_MULTIMODAL_0000001099_20220708_163014.csv
# KETI_MULTIMODAL_0000001074_20220708_163014.csv
# KETI_MULTIMODAL_0000001058_20220708_163014.csv
# KETI_MULTIMODAL_0000001057_20220708_163014.csv
# KETI_MULTIMODAL_0000001051_20220708_163014.csv
# KETI_MULTIMODAL_0000001075_20220708_163014.csv
# KETI_MULTIMODAL_0000001087_20220708_163014.csv
# KETI_MULTIMODAL_0000001062_20220708_163014.csv
# KETI_MULTIMODAL_0000001095_20220708_163014.csv
# KETI_MULTIMODAL_0000001043_20220708_163014.csv
# KETI_MULTIMODAL_0000001081_20220708_163014.csv
# ...

# %%
def repeat():
  for dr in dir_lst:
    df=pd.read_csv(dr)

# %%
df
# Out:
#     Index Modification  Speaker  Start Time  End Time  \
# 0       1         인식결과      NaN         360      1500
# 1       1         수정결과      NaN         360      1500
# 2       2         인식결과      NaN        4440      5980
# 3       2         수정결과      NaN        4440      5980
# 4       3         인식결과      NaN        6720      9800
# 5       3         수정결과      NaN        6720      9800
# 6       4         인식결과      NaN       13660     14920
# 7       4         수정결과      NaN       13660     14920
# 8       5         인식결과      NaN       15080     18740
# 9       5         수정결과      NaN       15080     18740
# 10      6         인식결과      NaN       19680     22000
# 11      6         수정결과      NaN       19680     22000
# 12      7         인식결과      NaN       24380     26480
# 13      7         수정결과      NaN       24380     26480
# 14      8         인식결과      NaN       27140     28660
# 15      8         수정결과      NaN       27140     28660
# ...

# %%
for d in dir_lst:
  print(d)
# Out:
# KETI_MULTIMODAL_0000001076_20220708_163014.csv
# KETI_MULTIMODAL_0000001077_20220708_163014.csv
# KETI_MULTIMODAL_0000001069_20220708_163014.csv
# KETI_MULTIMODAL_0000001098_20220708_163014.csv
# KETI_MULTIMODAL_0000001064_20220708_163014.csv
# KETI_MULTIMODAL_0000001091_20220708_163014.csv
# KETI_MULTIMODAL_0000001088_20220708_163014.csv
# KETI_MULTIMODAL_0000001096_20220708_163014.csv
# KETI_MULTIMODAL_0000001083_20220708_163014.csv
# KETI_MULTIMODAL_0000001099_20220708_163014.csv
# KETI_MULTIMODAL_0000001074_20220708_163014.csv
# KETI_MULTIMODAL_0000001058_20220708_163014.csv
# KETI_MULTIMODAL_0000001057_20220708_163014.csv
# KETI_MULTIMODAL_0000001051_20220708_163014.csv
# KETI_MULTIMODAL_0000001075_20220708_163014.csv
# KETI_MULTIMODAL_0000001087_20220708_163014.csv
# KETI_MULTIMODAL_0000001062_20220708_163014.csv
# KETI_MULTIMODAL_0000001095_20220708_163014.csv
# KETI_MULTIMODAL_0000001043_20220708_163014.csv
# KETI_MULTIMODAL_0000001081_20220708_163014.csv
# ...

# %%
df=pd.read_csv(dr)

# %%
df=df.dropna()

# %%
sample_df=df.iloc[0:49:2,-1]
sample_df
# Out:
# 0                                                     아
# 2               형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.
# 4                                      아 시끄러우면 집중 안 되는데
# 6                                공복이라서 예민하신 거 아닐까요. 작가님
# 8                                                   아 저
# 10                                 샌드위치 있습니다. 이것 좀 드세요.
# 12                아 무슨 소리지 나 방에서 음식도 안 먹는데 이거 당장 지워주세요.
# 14                                           아 네 죄송합니다.
# 16                                  아 죄송합니다. 어떡해 죄송합니다.
# 22           이거 닦으려면 잔물에 구연산하고 식초 뿌려서 팍팍 문질러 닦아질까 말까 한데
# 24                                          집에 구연산이 있던가
# 26                           야 너희가 발바닥 시커매 당장 화장실 가서 씻어
# 28                                                  아 형
# 30    아 내가 지금 그럴 만한 마음이 여유가 없어 나 방금 전에 사기까지 당하고 그리고 ...
# 32                                           야 당장 가서 시대
# 34           너 옷에 왜 이렇게 뭐 먼지가 많아 니 인생 마감하기 싫으면 당장 가서 씻어
# 36                                                  씻을게
# ...

# %%
script=[]
for i in sample_df:
  script.append(i)

# %%
script
# Out:
# ['아',
#  '형님분이 엄청 깔끔하신가 봅니다. 저희 온 뒤로 계속 청소만 하시네요.',
#  '아 시끄러우면 집중 안 되는데',
#  '공복이라서 예민하신 거 아닐까요. 작가님',
#  '아 저',
#  '샌드위치 있습니다. 이것 좀 드세요.',
#  '아 무슨 소리지 나 방에서 음식도 안 먹는데 이거 당장 지워주세요.',
#  '아 네 죄송합니다.',
#  '아 죄송합니다. 어떡해 죄송합니다.',
#  '이거 닦으려면 잔물에 구연산하고 식초 뿌려서 팍팍 문질러 닦아질까 말까 한데',
#  '집에 구연산이 있던가',
#  '야 너희가 발바닥 시커매 당장 화장실 가서 씻어',
#  '아 형',
#  '아 내가 지금 그럴 만한 마음이 여유가 없어 나 방금 전에 사기까지 당하고 그리고 마감까지 몇 시간 남지도 않았거든',
#  '야 당장 가서 시대',
#  '너 옷에 왜 이렇게 뭐 먼지가 많아 니 인생 마감하기 싫으면 당장 가서 씻어',
#  '씻을게',
#  '뭐 어디 그',
#  '이런 말을 어디 감히',
#  '바닥에 발바닥 대지 말고',
#  '발바닥 안 데고 어떻게 가',
#  '나 따라와',
#  '하 어서 뭐 해 따라와']
